# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Carregar dados
df = pd.read_csv('/home/rafelparracoelho/Área de Trabalho/VScode.py/analysis-turnover-rh/data/raw/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
# Entender o dataset
print("Shape:", df.shape)
print("\nColunas:", df.columns.tolist())
print("\nTipos:", df.dtypes)
print("\nInfo básica:")
print(df.info())
# Out:
# Shape: (1470, 35)
#
# Colunas: ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#
# Tipos: Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# ...

# %%
# Primeiras linhas
print("\nPrimeiras linhas:")
df.head()

# Valores faltantes
print("\nValores nulos:")
print(df.isnull().sum())

# Estatísticas descritivas
print("\nEstatísticas:")
df.describe()
# Out:
# Primeiras linhas:
#
# Valores nulos:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# ...

# %%
# Distribuição da variável target (Attrition)
print("\nDistribuição Attrition:")
print(df['Attrition'].value_counts())
print(df['Attrition'].value_counts(normalize=True))
# Out:
# Distribuição Attrition:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
# Contagem original
counts = df['Attrition'].value_counts()

# Mapeamento para PT-BR
labels_pt = counts.index.map({'Yes': 'Sim', 'No': 'Não'})

# Cores (Não em cinza, Sim destacado)
colors = [
    '#B0B0B0' if label == 'No' else '#001174'
    for label in counts.index
]

plt.figure(figsize=(9, 5))

ax = counts.plot(
    kind='bar',
    color=colors,
    edgecolor='black',
    width=0.55
)

# Títulos e labels
plt.title('Distribuição de Funcionários Afetados por Attrition', fontsize=14, weight='bold')
plt.xlabel('Status de Rotatividade', fontsize=11)
plt.ylabel('Número de Colaboradores', fontsize=11)
plt.figtext(
    0.5, -0.08,
   'A taxa de rotatividade é de 16,1%, acima da média do setor (12–13%), '
    'indicando potencial risco de retenção.',
    ha='center',
    fontsize=11,
    color='darkgray'
)
# 🔹 Aplicar labels traduzidos
ax.set_xticklabels(labels_pt, rotation=0)

# 🔹 Espaço no eixo Y
max_value = counts.max()
ax.set_ylim(0, max_value * 1.15)

# 🔹 Valores acima das barras
for i, v in enumerate(counts):
    ax.text(i, v + max_value * 0.03, str(v), ha='center', fontsize=10)

# Design clean
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()
